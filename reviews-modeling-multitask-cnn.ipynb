# %% [markdown]
# # Install & Import Dependencies

# %%
# !pip install ipython-autotime -q
# %load_ext autotime
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 3.23 s (started: 2025-02-06 12:12:45 +00:00)

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Bidirectional, LSTM, GlobalMaxPooling1D
from tensorflow.keras.layers import Input, Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D, Dense, Concatenate
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import AdamW
from gensim.models import Word2Vec
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import WordCloud
# Out:
# time: 998 µs (started: 2025-02-06 12:12:49 +00:00)

# %% [markdown]
# # Load Dataset

# %%
url = 'https://raw.githubusercontent.com/Fake-Sentiment-Review-Detection-Spiill/spiill-data-and-utils/refs/heads/main/spiill_reviews_preprocessed2.csv'
df_reviews = pd.read_csv(url)
df_reviews.tail(3)
# Out:
#         username  rate        date label sentimen  \
# 5897  eiswahyudi     3  2024-03-17   non  neutral
# 5898     dkusumo     5  2023-09-18   non  neutral
# 5899      adisti     3  2023-09-11   non  neutral
#
#                                                 reviews            produk  \
# 5897  Pasar saham Indonesia menunjukkan tren yang st...  Masker Skintific
# 5898  Penggunaan kendaraan listrik mulai diminati di...  Masker Skintific
# 5899                Lumayan lancar dengan berjalan baik  Masker Skintific
#
#                                 no_link_hashtag_reviews  \
# 5897  Pasar saham Indonesia menunjukkan tren yang st...
# 5898  Penggunaan kendaraan listrik mulai diminati di...
# 5899                Lumayan lancar dengan berjalan baik
#
#                                       no_emojis_reviews  \
# 5897  Pasar saham Indonesia menunjukkan tren yang st...
# 5898  Penggunaan kendaraan listrik mulai diminati di...
# 5899                Lumayan lancar dengan berjalan baik
#
#                                         no_html_reviews  \
# 5897  Pasar saham Indonesia menunjukkan tren yang st...
# 5898  Penggunaan kendaraan listrik mulai diminati di...
# 5899                Lumayan lancar dengan berjalan baik
#
#                                 no_special_char_reviews  \
# 5897  Pasar saham Indonesia menunjukkan tren yang st...
# 5898  Penggunaan kendaraan listrik mulai diminati di...
# 5899                Lumayan lancar dengan berjalan baik
#
#                                       no_number_reviews  \
# 5897  Pasar saham Indonesia menunjukkan tren yang st...
# 5898  Penggunaan kendaraan listrik mulai diminati di...
# 5899                Lumayan lancar dengan berjalan baik
#
#                                        no_punct_reviews  \
# 5897  Pasar saham Indonesia menunjukkan tren yang st...
# 5898  Penggunaan kendaraan listrik mulai diminati di...
# 5899                Lumayan lancar dengan berjalan baik
#
#                           no_whitespace_reviews_reviews  \
# 5897  Pasar saham Indonesia menunjukkan tren yang st...
# 5898  Penggunaan kendaraan listrik mulai diminati di...
# 5899                Lumayan lancar dengan berjalan baik
#
#                                       lowercase_reviews  \
# 5897  pasar saham indonesia menunjukkan tren yang st...
# 5898  penggunaan kendaraan listrik mulai diminati di...
# 5899                lumayan lancar dengan berjalan baik
#
#                                          tokens_reviews  \
# 5897  ['pasar', 'saham', 'indonesia', 'menunjukkan',...
# 5898  ['penggunaan', 'kendaraan', 'listrik', 'mulai'...
# 5899  ['lumayan', 'lancar', 'dengan', 'berjalan', 'b...
#
#                                    no_stopwords_reviews  \
# 5897  ['pasar', 'saham', 'indonesia', 'tren', 'stabil']
# 5898  ['penggunaan', 'kendaraan', 'listrik', 'dimina...
# 5899                  ['lumayan', 'lancar', 'berjalan']
#
#                                      normalized_reviews  \
# 5897  ['pasar', 'saham', 'indonesia', 'tren', 'stabil']
# 5898  ['penggunaan', 'kendaraan', 'listrik', 'dimina...
# 5899                  ['lumayan', 'lancar', 'berjalan']
#
#                                         stemmed_reviews
# 5897  ['pasar', 'saham', 'indonesia', 'tren', 'stabil']
# 5898     ['guna', 'kendara', 'listrik', 'mati', 'kota']
# 5899                     ['lumayan', 'lancar', 'jalan']
# time: 358 ms (started: 2025-02-06 12:12:49 +00:00)

# %%
df_reviews.sentimen.value_counts()
# Out:
# sentimen
# positive    3686
# neutral     1352
# negative     862
# Name: count, dtype: int64
# time: 3.47 ms (started: 2025-02-06 12:12:49 +00:00)

# %%
df_reviews.label.value_counts()
# Out:
# label
# trusted    3912
# non        1150
# fake        838
# Name: count, dtype: int64
# time: 11.5 ms (started: 2025-02-06 12:12:49 +00:00)

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Model Function Preparation

# %%
def preprocess_data(df):
    # Convert string representations of lists to actual lists
    def safe_eval(x):
        try:
            if isinstance(x, list):
                return x
            elif isinstance(x, str):
                # Remove square brackets and split by comma
                x = x.strip('[]')
                # Split by comma and clean up each word
                words = [word.strip().strip("'").strip('"') for word in x.split(',')]
                return [word for word in words if word]
            return []
        except:
            return []

    # Convert stemmed_reviews to list format
    df['stemmed_reviews'] = df['stemmed_reviews'].apply(safe_eval)
    
    # Create text sequences
    texts = df['stemmed_reviews'].tolist()
    
    # Train Word2Vec model
    word2vec_model = Word2Vec(texts, vector_size=100, window=5, min_count=1, workers=4)
    
    # Create tokenizer
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(texts)
    
    # Convert texts to sequences
    sequences = tokenizer.texts_to_sequences(texts)
    
    # Pad sequences
    max_len = max(len(seq) for seq in sequences)
    padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post')
    
    # Create embedding matrix
    vocab_size = len(tokenizer.word_index) + 1
    embedding_matrix = np.zeros((vocab_size, 100))
    
    for word, i in tokenizer.word_index.items():
        if word in word2vec_model.wv:
            embedding_matrix[i] = word2vec_model.wv[word]
    
    return padded_sequences, embedding_matrix, vocab_size, max_len, tokenizer

def create_cnn_model(vocab_size, embedding_matrix, max_len):
    # Input layer
    input_layer = Input(shape=(max_len,))
    
    # Embedding layer with pre-trained weights
    embedding_layer = Embedding(
        vocab_size,
        100,
        weights=[embedding_matrix],
        input_length=max_len,
        trainable=False
    )(input_layer)
    
    # First Conv1D Layer
    conv1 = Conv1D(filters=128, kernel_size=5, activation='relu')(embedding_layer)
    pool1 = MaxPooling1D(pool_size=2)(conv1)
    
    # Second Conv1D Layer
    conv2 = Conv1D(filters=128, kernel_size=5, activation='relu')(pool1)
    global_pool = GlobalMaxPooling1D()(conv2)
    
    # Output layers
    sentiment_output = Dense(3, activation='softmax', name='sentiment')(global_pool)
    label_output = Dense(3, activation='softmax', name='label')(global_pool)
    
    # Create model
    model = Model(
        inputs=input_layer,
        outputs=[sentiment_output, label_output]
    )
    
    # Initialize AdamW optimizer with learning rate
    optimizer = AdamW(learning_rate=1e-5)
    
    # Compile model
    model.compile(
        optimizer=optimizer,
        loss={
            'sentiment': 'categorical_crossentropy',
            'label': 'categorical_crossentropy'
        },
        metrics={
            'sentiment': 'accuracy',
            'label': 'accuracy'
        }
    )
    
    return model

def train_cnn_model(df):
    # Preprocess text data
    X, embedding_matrix, vocab_size, max_len, tokenizer = preprocess_data(df)
    
    # Prepare labels
    sentiment_encoder = LabelEncoder()
    label_encoder = LabelEncoder()
    
    y_sentiment = sentiment_encoder.fit_transform(df['sentimen'])
    y_label = label_encoder.fit_transform(df['label'])
    
    # Convert to categorical
    y_sentiment = tf.keras.utils.to_categorical(y_sentiment)
    y_label = tf.keras.utils.to_categorical(y_label)
    
    # Split data
    X_train, X_test, y_sentiment_train, y_sentiment_test, y_label_train, y_label_test = train_test_split(
        X, y_sentiment, y_label, test_size=0.2, random_state=42
    )
    
    # Define callbacks
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        mode='min'
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=5,
        min_lr=1e-7,
        mode='min'
    )
    
    # Create and train model
    model = create_cnn_model(vocab_size, embedding_matrix, max_len)
    
    history = model.fit(
        X_train,
        {
            'sentiment': y_sentiment_train,
            'label': y_label_train
        },
        validation_data=(
            X_test,
            {
                'sentiment': y_sentiment_test,
                'label': y_label_test
            }
        ),
        epochs=1000,
        batch_size=32,
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )
    
    return (model, history, sentiment_encoder, label_encoder, tokenizer, max_len,
            X_test, y_sentiment_test, y_label_test)

def evaluate_model(model, X_test, y_sentiment_test, y_label_test, sentiment_encoder, label_encoder):
    # Get predictions
    sentiment_pred, label_pred = model.predict(X_test)
    
    # Convert predictions to class labels
    sentiment_pred_classes = np.argmax(sentiment_pred, axis=1)
    label_pred_classes = np.argmax(label_pred, axis=1)
    
    sentiment_true_classes = np.argmax(y_sentiment_test, axis=1)
    label_true_classes = np.argmax(y_label_test, axis=1)
    
    # Get original class names
    sentiment_classes = sentiment_encoder.classes_
    label_classes = label_encoder.classes_
    
    # Print Classification Reports
    print("\nSentiment Classification Report:")
    print(classification_report(sentiment_true_classes, sentiment_pred_classes, 
                              target_names=sentiment_classes))
    
    print("\nLabel Classification Report:")
    print(classification_report(label_true_classes, label_pred_classes, 
                              target_names=label_classes))
    
    # Create Confusion Matrices
    def plot_confusion_matrix(true_classes, pred_classes, classes, title):
        cm = confusion_matrix(true_classes, pred_classes)
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                   xticklabels=classes, yticklabels=classes)
        plt.title(title)
        plt.ylabel('True Label')
        plt.xlabel('Predicted Label')
        plt.tight_layout()
        plt.show()
    
    # Plot Confusion Matrices
    plot_confusion_matrix(sentiment_true_classes, sentiment_pred_classes, 
                         sentiment_classes, 'Sentiment Confusion Matrix')
    plot_confusion_matrix(label_true_classes, label_pred_classes, 
                         label_classes, 'Label Confusion Matrix')
    
    return {
        'sentiment_report': classification_report(sentiment_true_classes, 
                                                sentiment_pred_classes, 
                                                target_names=sentiment_classes, 
                                                output_dict=True),
        'label_report': classification_report(label_true_classes, 
                                            label_pred_classes, 
                                            target_names=label_classes, 
                                            output_dict=True),
        'sentiment_cm': confusion_matrix(sentiment_true_classes, sentiment_pred_classes),
        'label_cm': confusion_matrix(label_true_classes, label_pred_classes)
    }

def predict_text(text, model, tokenizer, sentiment_encoder, label_encoder, max_len):
    # Preprocess input text
    sequence = tokenizer.texts_to_sequences([text])
    padded = pad_sequences(sequence, maxlen=max_len, padding='post')
    
    # Make prediction
    sentiment_pred, label_pred = model.predict(padded)
    
    # Convert predictions to classes
    sentiment = sentiment_encoder.inverse_transform([np.argmax(sentiment_pred[0])])[0]
    label = label_encoder.inverse_transform([np.argmax(label_pred[0])])[0]
    
    return sentiment, label
# Out:
# time: 3.71 ms (started: 2025-02-06 12:12:49 +00:00)

# %% [markdown]
# ## Train Model

# %%
(model, history, sentiment_encoder, label_encoder, tokenizer, max_len,
 X_test, y_sentiment_test, y_label_test) = train_cnn_model(df_reviews)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - label_accuracy: 0.6385 - label_loss: 0.9970 - loss: 1.9652 - sentiment_accuracy: 0.5124 - sentiment_loss: 0.9683 - val_label_accuracy: 0.6627 - val_label_loss: 0.8785 - val_loss: 1.5934 - val_sentiment_accuracy: 0.6229 - val_sentiment_loss: 0.7156 - learning_rate: 1.0000e-05
# Epoch 2/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.6706 - label_loss: 0.8729 - loss: 1.5650 - sentiment_accuracy: 0.6163 - sentiment_loss: 0.6921 - val_label_accuracy: 0.6627 - val_label_loss: 0.8680 - val_loss: 1.5391 - val_sentiment_accuracy: 0.6297 - val_sentiment_loss: 0.6720 - learning_rate: 1.0000e-05
# Epoch 3/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.6664 - label_loss: 0.8764 - loss: 1.5386 - sentiment_accuracy: 0.6201 - sentiment_loss: 0.6621 - val_label_accuracy: 0.6627 - val_label_loss: 0.8628 - val_loss: 1.5092 - val_sentiment_accuracy: 0.6381 - val_sentiment_loss: 0.6473 - learning_rate: 1.0000e-05
# Epoch 4/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.6724 - label_loss: 0.8582 - loss: 1.4903 - sentiment_accuracy: 0.6509 - sentiment_loss: 0.6321 - val_label_accuracy: 0.6703 - val_label_loss: 0.8575 - val_loss: 1.4827 - val_sentiment_accuracy: 0.6449 - val_sentiment_loss: 0.6261 - learning_rate: 1.0000e-05
# Epoch 5/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.6793 - label_loss: 0.8449 - loss: 1.4730 - sentiment_accuracy: 0.6614 - sentiment_loss: 0.6281 - val_label_accuracy: 0.6780 - val_label_loss: 0.8537 - val_loss: 1.4599 - val_sentiment_accuracy: 0.6475 - val_sentiment_loss: 0.6071 - learning_rate: 1.0000e-05
# Epoch 6/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - label_accuracy: 0.6863 - label_loss: 0.8524 - loss: 1.4720 - sentiment_accuracy: 0.6541 - sentiment_loss: 0.6196 - val_label_accuracy: 0.7059 - val_label_loss: 0.8507 - val_loss: 1.4409 - val_sentiment_accuracy: 0.6475 - val_sentiment_loss: 0.5911 - learning_rate: 1.0000e-05
# Epoch 7/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7135 - label_loss: 0.8404 - loss: 1.4318 - sentiment_accuracy: 0.6571 - sentiment_loss: 0.5914 - val_label_accuracy: 0.7347 - val_label_loss: 0.8479 - val_loss: 1.4264 - val_sentiment_accuracy: 0.6432 - val_sentiment_loss: 0.5795 - learning_rate: 1.0000e-05
# Epoch 8/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7386 - label_loss: 0.8392 - loss: 1.4253 - sentiment_accuracy: 0.6589 - sentiment_loss: 0.5861 - val_label_accuracy: 0.7525 - val_label_loss: 0.8461 - val_loss: 1.4146 - val_sentiment_accuracy: 0.6432 - val_sentiment_loss: 0.5696 - learning_rate: 1.0000e-05
# Epoch 9/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7532 - label_loss: 0.8407 - loss: 1.4016 - sentiment_accuracy: 0.6551 - sentiment_loss: 0.5609 - val_label_accuracy: 0.7585 - val_label_loss: 0.8442 - val_loss: 1.4029 - val_sentiment_accuracy: 0.6441 - val_sentiment_loss: 0.5598 - learning_rate: 1.0000e-05
# Epoch 10/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7539 - label_loss: 0.8490 - loss: 1.4081 - sentiment_accuracy: 0.6422 - sentiment_loss: 0.5591 - val_label_accuracy: 0.7661 - val_label_loss: 0.8430 - val_loss: 1.3952 - val_sentiment_accuracy: 0.6432 - val_sentiment_loss: 0.5533 - learning_rate: 1.0000e-05
# Epoch 11/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7586 - label_loss: 0.8319 - loss: 1.3996 - sentiment_accuracy: 0.6555 - sentiment_loss: 0.5677 - val_label_accuracy: 0.7661 - val_label_loss: 0.8415 - val_loss: 1.3864 - val_sentiment_accuracy: 0.6415 - val_sentiment_loss: 0.5460 - learning_rate: 1.0000e-05
# Epoch 12/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7637 - label_loss: 0.8290 - loss: 1.3797 - sentiment_accuracy: 0.6583 - sentiment_loss: 0.5507 - val_label_accuracy: 0.7729 - val_label_loss: 0.8415 - val_loss: 1.3822 - val_sentiment_accuracy: 0.6432 - val_sentiment_loss: 0.5418 - learning_rate: 1.0000e-05
# Epoch 13/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7620 - label_loss: 0.8178 - loss: 1.3640 - sentiment_accuracy: 0.6597 - sentiment_loss: 0.5462 - val_label_accuracy: 0.7746 - val_label_loss: 0.8402 - val_loss: 1.3761 - val_sentiment_accuracy: 0.6424 - val_sentiment_loss: 0.5370 - learning_rate: 1.0000e-05
# Epoch 14/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7662 - label_loss: 0.8371 - loss: 1.3929 - sentiment_accuracy: 0.6479 - sentiment_loss: 0.5558 - val_label_accuracy: 0.7737 - val_label_loss: 0.8381 - val_loss: 1.3707 - val_sentiment_accuracy: 0.6449 - val_sentiment_loss: 0.5338 - learning_rate: 1.0000e-05
# Epoch 15/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - label_accuracy: 0.7729 - label_loss: 0.8188 - loss: 1.3575 - sentiment_accuracy: 0.6616 - sentiment_loss: 0.5387 - val_label_accuracy: 0.7754 - val_label_loss: 0.8376 - val_loss: 1.3651 - val_sentiment_accuracy: 0.6432 - val_sentiment_loss: 0.5286 - learning_rate: 1.0000e-05
# Epoch 16/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7717 - label_loss: 0.8290 - loss: 1.3515 - sentiment_accuracy: 0.6562 - sentiment_loss: 0.5225 - val_label_accuracy: 0.7729 - val_label_loss: 0.8372 - val_loss: 1.3622 - val_sentiment_accuracy: 0.6415 - val_sentiment_loss: 0.5261 - learning_rate: 1.0000e-05
# Epoch 17/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7648 - label_loss: 0.8217 - loss: 1.3633 - sentiment_accuracy: 0.6564 - sentiment_loss: 0.5416 - val_label_accuracy: 0.7763 - val_label_loss: 0.8364 - val_loss: 1.3580 - val_sentiment_accuracy: 0.6424 - val_sentiment_loss: 0.5227 - learning_rate: 1.0000e-05
# Epoch 18/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7681 - label_loss: 0.8213 - loss: 1.3435 - sentiment_accuracy: 0.6567 - sentiment_loss: 0.5222 - val_label_accuracy: 0.7754 - val_label_loss: 0.8356 - val_loss: 1.3535 - val_sentiment_accuracy: 0.6432 - val_sentiment_loss: 0.5191 - learning_rate: 1.0000e-05
# Epoch 19/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7819 - label_loss: 0.8051 - loss: 1.3132 - sentiment_accuracy: 0.6662 - sentiment_loss: 0.5081 - val_label_accuracy: 0.7771 - val_label_loss: 0.8355 - val_loss: 1.3501 - val_sentiment_accuracy: 0.6449 - val_sentiment_loss: 0.5158 - learning_rate: 1.0000e-05
# Epoch 20/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7686 - label_loss: 0.8336 - loss: 1.3453 - sentiment_accuracy: 0.6524 - sentiment_loss: 0.5118 - val_label_accuracy: 0.7771 - val_label_loss: 0.8348 - val_loss: 1.3477 - val_sentiment_accuracy: 0.6432 - val_sentiment_loss: 0.5141 - learning_rate: 1.0000e-05
# Epoch 21/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7683 - label_loss: 0.8116 - loss: 1.3367 - sentiment_accuracy: 0.6600 - sentiment_loss: 0.5251 - val_label_accuracy: 0.7746 - val_label_loss: 0.8338 - val_loss: 1.3443 - val_sentiment_accuracy: 0.6441 - val_sentiment_loss: 0.5117 - learning_rate: 1.0000e-05
# Epoch 22/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7717 - label_loss: 0.8342 - loss: 1.3469 - sentiment_accuracy: 0.6446 - sentiment_loss: 0.5127 - val_label_accuracy: 0.7754 - val_label_loss: 0.8336 - val_loss: 1.3409 - val_sentiment_accuracy: 0.6458 - val_sentiment_loss: 0.5085 - learning_rate: 1.0000e-05
# Epoch 23/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7785 - label_loss: 0.8149 - loss: 1.3151 - sentiment_accuracy: 0.6588 - sentiment_loss: 0.5002 - val_label_accuracy: 0.7737 - val_label_loss: 0.8333 - val_loss: 1.3411 - val_sentiment_accuracy: 0.6458 - val_sentiment_loss: 0.5091 - learning_rate: 1.0000e-05
# Epoch 24/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7780 - label_loss: 0.8324 - loss: 1.3356 - sentiment_accuracy: 0.6557 - sentiment_loss: 0.5032 - val_label_accuracy: 0.7771 - val_label_loss: 0.8341 - val_loss: 1.3379 - val_sentiment_accuracy: 0.6432 - val_sentiment_loss: 0.5050 - learning_rate: 1.0000e-05
# Epoch 25/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7696 - label_loss: 0.8167 - loss: 1.3308 - sentiment_accuracy: 0.6530 - sentiment_loss: 0.5141 - val_label_accuracy: 0.7746 - val_label_loss: 0.8320 - val_loss: 1.3369 - val_sentiment_accuracy: 0.6449 - val_sentiment_loss: 0.5061 - learning_rate: 1.0000e-05
# Epoch 26/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7818 - label_loss: 0.8070 - loss: 1.2988 - sentiment_accuracy: 0.6635 - sentiment_loss: 0.4918 - val_label_accuracy: 0.7763 - val_label_loss: 0.8320 - val_loss: 1.3342 - val_sentiment_accuracy: 0.6432 - val_sentiment_loss: 0.5035 - learning_rate: 1.0000e-05
# Epoch 27/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7749 - label_loss: 0.8173 - loss: 1.3219 - sentiment_accuracy: 0.6600 - sentiment_loss: 0.5046 - val_label_accuracy: 0.7746 - val_label_loss: 0.8315 - val_loss: 1.3303 - val_sentiment_accuracy: 0.6441 - val_sentiment_loss: 0.5001 - learning_rate: 1.0000e-05
# Epoch 28/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7669 - label_loss: 0.8295 - loss: 1.3254 - sentiment_accuracy: 0.6432 - sentiment_loss: 0.4958 - val_label_accuracy: 0.7754 - val_label_loss: 0.8313 - val_loss: 1.3289 - val_sentiment_accuracy: 0.6449 - val_sentiment_loss: 0.4988 - learning_rate: 1.0000e-05
# Epoch 29/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7658 - label_loss: 0.8203 - loss: 1.3204 - sentiment_accuracy: 0.6511 - sentiment_loss: 0.5001 - val_label_accuracy: 0.7746 - val_label_loss: 0.8316 - val_loss: 1.3287 - val_sentiment_accuracy: 0.6424 - val_sentiment_loss: 0.4983 - learning_rate: 1.0000e-05
# Epoch 30/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7701 - label_loss: 0.8207 - loss: 1.3211 - sentiment_accuracy: 0.6535 - sentiment_loss: 0.5004 - val_label_accuracy: 0.7754 - val_label_loss: 0.8306 - val_loss: 1.3256 - val_sentiment_accuracy: 0.6441 - val_sentiment_loss: 0.4962 - learning_rate: 1.0000e-05
# Epoch 31/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7721 - label_loss: 0.8083 - loss: 1.3002 - sentiment_accuracy: 0.6640 - sentiment_loss: 0.4919 - val_label_accuracy: 0.7754 - val_label_loss: 0.8301 - val_loss: 1.3245 - val_sentiment_accuracy: 0.6449 - val_sentiment_loss: 0.4957 - learning_rate: 1.0000e-05
# Epoch 32/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7668 - label_loss: 0.8100 - loss: 1.3151 - sentiment_accuracy: 0.6568 - sentiment_loss: 0.5051 - val_label_accuracy: 0.7763 - val_label_loss: 0.8294 - val_loss: 1.3222 - val_sentiment_accuracy: 0.6458 - val_sentiment_loss: 0.4940 - learning_rate: 1.0000e-05
# Epoch 33/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7666 - label_loss: 0.8100 - loss: 1.3030 - sentiment_accuracy: 0.6641 - sentiment_loss: 0.4930 - val_label_accuracy: 0.7763 - val_label_loss: 0.8300 - val_loss: 1.3217 - val_sentiment_accuracy: 0.6475 - val_sentiment_loss: 0.4930 - learning_rate: 1.0000e-05
# Epoch 34/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - label_accuracy: 0.7766 - label_loss: 0.7990 - loss: 1.2902 - sentiment_accuracy: 0.6658 - sentiment_loss: 0.4912 - val_label_accuracy: 0.7763 - val_label_loss: 0.8286 - val_loss: 1.3201 - val_sentiment_accuracy: 0.6449 - val_sentiment_loss: 0.4927 - learning_rate: 1.0000e-05
# Epoch 35/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7707 - label_loss: 0.8201 - loss: 1.3255 - sentiment_accuracy: 0.6535 - sentiment_loss: 0.5055 - val_label_accuracy: 0.7737 - val_label_loss: 0.8286 - val_loss: 1.3188 - val_sentiment_accuracy: 0.6458 - val_sentiment_loss: 0.4915 - learning_rate: 1.0000e-05
# Epoch 36/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7700 - label_loss: 0.8212 - loss: 1.3253 - sentiment_accuracy: 0.6539 - sentiment_loss: 0.5041 - val_label_accuracy: 0.7754 - val_label_loss: 0.8277 - val_loss: 1.3152 - val_sentiment_accuracy: 0.6475 - val_sentiment_loss: 0.4888 - learning_rate: 1.0000e-05
# Epoch 37/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7650 - label_loss: 0.8077 - loss: 1.2980 - sentiment_accuracy: 0.6499 - sentiment_loss: 0.4903 - val_label_accuracy: 0.7746 - val_label_loss: 0.8272 - val_loss: 1.3157 - val_sentiment_accuracy: 0.6475 - val_sentiment_loss: 0.4898 - learning_rate: 1.0000e-05
# Epoch 38/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - label_accuracy: 0.7671 - label_loss: 0.8087 - loss: 1.3106 - sentiment_accuracy: 0.6633 - sentiment_loss: 0.5020 - val_label_accuracy: 0.7771 - val_label_loss: 0.8275 - val_loss: 1.3139 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4877 - learning_rate: 1.0000e-05
# Epoch 39/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - label_accuracy: 0.7679 - label_loss: 0.8079 - loss: 1.2975 - sentiment_accuracy: 0.6640 - sentiment_loss: 0.4897 - val_label_accuracy: 0.7746 - val_label_loss: 0.8269 - val_loss: 1.3135 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4879 - learning_rate: 1.0000e-05
# Epoch 40/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7756 - label_loss: 0.8140 - loss: 1.3068 - sentiment_accuracy: 0.6542 - sentiment_loss: 0.4928 - val_label_accuracy: 0.7754 - val_label_loss: 0.8272 - val_loss: 1.3132 - val_sentiment_accuracy: 0.6475 - val_sentiment_loss: 0.4873 - learning_rate: 1.0000e-05
# Epoch 41/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7775 - label_loss: 0.8049 - loss: 1.2733 - sentiment_accuracy: 0.6614 - sentiment_loss: 0.4685 - val_label_accuracy: 0.7771 - val_label_loss: 0.8265 - val_loss: 1.3112 - val_sentiment_accuracy: 0.6466 - val_sentiment_loss: 0.4859 - learning_rate: 1.0000e-05
# Epoch 42/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7692 - label_loss: 0.8047 - loss: 1.2884 - sentiment_accuracy: 0.6557 - sentiment_loss: 0.4838 - val_label_accuracy: 0.7746 - val_label_loss: 0.8253 - val_loss: 1.3095 - val_sentiment_accuracy: 0.6458 - val_sentiment_loss: 0.4855 - learning_rate: 1.0000e-05
# Epoch 43/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7772 - label_loss: 0.7970 - loss: 1.2696 - sentiment_accuracy: 0.6591 - sentiment_loss: 0.4726 - val_label_accuracy: 0.7754 - val_label_loss: 0.8250 - val_loss: 1.3087 - val_sentiment_accuracy: 0.6458 - val_sentiment_loss: 0.4850 - learning_rate: 1.0000e-05
# Epoch 44/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7767 - label_loss: 0.7975 - loss: 1.2864 - sentiment_accuracy: 0.6602 - sentiment_loss: 0.4889 - val_label_accuracy: 0.7788 - val_label_loss: 0.8251 - val_loss: 1.3085 - val_sentiment_accuracy: 0.6449 - val_sentiment_loss: 0.4847 - learning_rate: 1.0000e-05
# Epoch 45/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7724 - label_loss: 0.8064 - loss: 1.2690 - sentiment_accuracy: 0.6470 - sentiment_loss: 0.4626 - val_label_accuracy: 0.7746 - val_label_loss: 0.8248 - val_loss: 1.3053 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4818 - learning_rate: 1.0000e-05
# Epoch 46/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7636 - label_loss: 0.7986 - loss: 1.2790 - sentiment_accuracy: 0.6525 - sentiment_loss: 0.4804 - val_label_accuracy: 0.7763 - val_label_loss: 0.8254 - val_loss: 1.3062 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4821 - learning_rate: 1.0000e-05
# Epoch 47/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7813 - label_loss: 0.7941 - loss: 1.2486 - sentiment_accuracy: 0.6645 - sentiment_loss: 0.4544 - val_label_accuracy: 0.7788 - val_label_loss: 0.8242 - val_loss: 1.3039 - val_sentiment_accuracy: 0.6475 - val_sentiment_loss: 0.4811 - learning_rate: 1.0000e-05
# Epoch 48/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7620 - label_loss: 0.8107 - loss: 1.3028 - sentiment_accuracy: 0.6434 - sentiment_loss: 0.4921 - val_label_accuracy: 0.7771 - val_label_loss: 0.8241 - val_loss: 1.3031 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4803 - learning_rate: 1.0000e-05
# Epoch 49/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7679 - label_loss: 0.8103 - loss: 1.3051 - sentiment_accuracy: 0.6491 - sentiment_loss: 0.4947 - val_label_accuracy: 0.7771 - val_label_loss: 0.8248 - val_loss: 1.3052 - val_sentiment_accuracy: 0.6466 - val_sentiment_loss: 0.4817 - learning_rate: 1.0000e-05
# Epoch 50/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7708 - label_loss: 0.7933 - loss: 1.2685 - sentiment_accuracy: 0.6594 - sentiment_loss: 0.4752 - val_label_accuracy: 0.7788 - val_label_loss: 0.8238 - val_loss: 1.3013 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4789 - learning_rate: 1.0000e-05
# Epoch 51/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7728 - label_loss: 0.7976 - loss: 1.2736 - sentiment_accuracy: 0.6618 - sentiment_loss: 0.4760 - val_label_accuracy: 0.7771 - val_label_loss: 0.8231 - val_loss: 1.3003 - val_sentiment_accuracy: 0.6475 - val_sentiment_loss: 0.4785 - learning_rate: 1.0000e-05
# Epoch 52/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7728 - label_loss: 0.7889 - loss: 1.2564 - sentiment_accuracy: 0.6584 - sentiment_loss: 0.4675 - val_label_accuracy: 0.7814 - val_label_loss: 0.8246 - val_loss: 1.3011 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4778 - learning_rate: 1.0000e-05
# Epoch 53/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7740 - label_loss: 0.7930 - loss: 1.2709 - sentiment_accuracy: 0.6646 - sentiment_loss: 0.4779 - val_label_accuracy: 0.7780 - val_label_loss: 0.8222 - val_loss: 1.2988 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4779 - learning_rate: 1.0000e-05
# Epoch 54/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7838 - label_loss: 0.7796 - loss: 1.2277 - sentiment_accuracy: 0.6710 - sentiment_loss: 0.4481 - val_label_accuracy: 0.7754 - val_label_loss: 0.8225 - val_loss: 1.2988 - val_sentiment_accuracy: 0.6466 - val_sentiment_loss: 0.4776 - learning_rate: 1.0000e-05
# Epoch 55/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7699 - label_loss: 0.7877 - loss: 1.2636 - sentiment_accuracy: 0.6556 - sentiment_loss: 0.4759 - val_label_accuracy: 0.7788 - val_label_loss: 0.8217 - val_loss: 1.2965 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4761 - learning_rate: 1.0000e-05
# Epoch 56/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7720 - label_loss: 0.7941 - loss: 1.2586 - sentiment_accuracy: 0.6530 - sentiment_loss: 0.4644 - val_label_accuracy: 0.7754 - val_label_loss: 0.8214 - val_loss: 1.2964 - val_sentiment_accuracy: 0.6466 - val_sentiment_loss: 0.4764 - learning_rate: 1.0000e-05
# Epoch 57/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7739 - label_loss: 0.8024 - loss: 1.2653 - sentiment_accuracy: 0.6488 - sentiment_loss: 0.4629 - val_label_accuracy: 0.7763 - val_label_loss: 0.8237 - val_loss: 1.2992 - val_sentiment_accuracy: 0.6500 - val_sentiment_loss: 0.4769 - learning_rate: 1.0000e-05
# Epoch 58/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7716 - label_loss: 0.7949 - loss: 1.2513 - sentiment_accuracy: 0.6535 - sentiment_loss: 0.4564 - val_label_accuracy: 0.7763 - val_label_loss: 0.8208 - val_loss: 1.2961 - val_sentiment_accuracy: 0.6508 - val_sentiment_loss: 0.4766 - learning_rate: 1.0000e-05
# Epoch 59/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7630 - label_loss: 0.7941 - loss: 1.2903 - sentiment_accuracy: 0.6544 - sentiment_loss: 0.4961 - val_label_accuracy: 0.7780 - val_label_loss: 0.8214 - val_loss: 1.2954 - val_sentiment_accuracy: 0.6500 - val_sentiment_loss: 0.4754 - learning_rate: 1.0000e-05
# Epoch 60/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7717 - label_loss: 0.7763 - loss: 1.2465 - sentiment_accuracy: 0.6646 - sentiment_loss: 0.4701 - val_label_accuracy: 0.7746 - val_label_loss: 0.8203 - val_loss: 1.2947 - val_sentiment_accuracy: 0.6500 - val_sentiment_loss: 0.4757 - learning_rate: 1.0000e-05
# Epoch 61/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7666 - label_loss: 0.7994 - loss: 1.2867 - sentiment_accuracy: 0.6493 - sentiment_loss: 0.4873 - val_label_accuracy: 0.7746 - val_label_loss: 0.8197 - val_loss: 1.2932 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4748 - learning_rate: 1.0000e-05
# Epoch 62/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7801 - label_loss: 0.7744 - loss: 1.2166 - sentiment_accuracy: 0.6660 - sentiment_loss: 0.4422 - val_label_accuracy: 0.7746 - val_label_loss: 0.8206 - val_loss: 1.2937 - val_sentiment_accuracy: 0.6500 - val_sentiment_loss: 0.4744 - learning_rate: 1.0000e-05
# Epoch 63/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7737 - label_loss: 0.7922 - loss: 1.2703 - sentiment_accuracy: 0.6545 - sentiment_loss: 0.4781 - val_label_accuracy: 0.7788 - val_label_loss: 0.8204 - val_loss: 1.2947 - val_sentiment_accuracy: 0.6500 - val_sentiment_loss: 0.4757 - learning_rate: 1.0000e-05
# Epoch 64/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7876 - label_loss: 0.7625 - loss: 1.2191 - sentiment_accuracy: 0.6747 - sentiment_loss: 0.4567 - val_label_accuracy: 0.7754 - val_label_loss: 0.8194 - val_loss: 1.2912 - val_sentiment_accuracy: 0.6475 - val_sentiment_loss: 0.4732 - learning_rate: 1.0000e-05
# Epoch 65/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7695 - label_loss: 0.7836 - loss: 1.2500 - sentiment_accuracy: 0.6570 - sentiment_loss: 0.4664 - val_label_accuracy: 0.7746 - val_label_loss: 0.8189 - val_loss: 1.2903 - val_sentiment_accuracy: 0.6449 - val_sentiment_loss: 0.4727 - learning_rate: 1.0000e-05
# Epoch 66/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7664 - label_loss: 0.7696 - loss: 1.2322 - sentiment_accuracy: 0.6630 - sentiment_loss: 0.4626 - val_label_accuracy: 0.7797 - val_label_loss: 0.8205 - val_loss: 1.2915 - val_sentiment_accuracy: 0.6475 - val_sentiment_loss: 0.4724 - learning_rate: 1.0000e-05
# Epoch 67/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7722 - label_loss: 0.7819 - loss: 1.2514 - sentiment_accuracy: 0.6544 - sentiment_loss: 0.4695 - val_label_accuracy: 0.7771 - val_label_loss: 0.8185 - val_loss: 1.2881 - val_sentiment_accuracy: 0.6500 - val_sentiment_loss: 0.4709 - learning_rate: 1.0000e-05
# Epoch 68/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7772 - label_loss: 0.7754 - loss: 1.2306 - sentiment_accuracy: 0.6590 - sentiment_loss: 0.4552 - val_label_accuracy: 0.7805 - val_label_loss: 0.8200 - val_loss: 1.2899 - val_sentiment_accuracy: 0.6500 - val_sentiment_loss: 0.4713 - learning_rate: 1.0000e-05
# Epoch 69/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7763 - label_loss: 0.7847 - loss: 1.2292 - sentiment_accuracy: 0.6529 - sentiment_loss: 0.4444 - val_label_accuracy: 0.7805 - val_label_loss: 0.8185 - val_loss: 1.2874 - val_sentiment_accuracy: 0.6517 - val_sentiment_loss: 0.4703 - learning_rate: 1.0000e-05
# Epoch 70/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7763 - label_loss: 0.7741 - loss: 1.2413 - sentiment_accuracy: 0.6679 - sentiment_loss: 0.4672 - val_label_accuracy: 0.7771 - val_label_loss: 0.8175 - val_loss: 1.2860 - val_sentiment_accuracy: 0.6500 - val_sentiment_loss: 0.4698 - learning_rate: 1.0000e-05
# Epoch 71/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7757 - label_loss: 0.7693 - loss: 1.2200 - sentiment_accuracy: 0.6630 - sentiment_loss: 0.4508 - val_label_accuracy: 0.7822 - val_label_loss: 0.8188 - val_loss: 1.2875 - val_sentiment_accuracy: 0.6466 - val_sentiment_loss: 0.4700 - learning_rate: 1.0000e-05
# Epoch 72/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7835 - label_loss: 0.7829 - loss: 1.2302 - sentiment_accuracy: 0.6576 - sentiment_loss: 0.4473 - val_label_accuracy: 0.7788 - val_label_loss: 0.8170 - val_loss: 1.2857 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4700 - learning_rate: 1.0000e-05
# Epoch 73/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7717 - label_loss: 0.7796 - loss: 1.2286 - sentiment_accuracy: 0.6608 - sentiment_loss: 0.4491 - val_label_accuracy: 0.7771 - val_label_loss: 0.8168 - val_loss: 1.2841 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4686 - learning_rate: 1.0000e-05
# Epoch 74/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7753 - label_loss: 0.7849 - loss: 1.2456 - sentiment_accuracy: 0.6521 - sentiment_loss: 0.4607 - val_label_accuracy: 0.7771 - val_label_loss: 0.8170 - val_loss: 1.2879 - val_sentiment_accuracy: 0.6475 - val_sentiment_loss: 0.4722 - learning_rate: 1.0000e-05
# Epoch 75/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7749 - label_loss: 0.7729 - loss: 1.2280 - sentiment_accuracy: 0.6646 - sentiment_loss: 0.4551 - val_label_accuracy: 0.7814 - val_label_loss: 0.8171 - val_loss: 1.2855 - val_sentiment_accuracy: 0.6517 - val_sentiment_loss: 0.4699 - learning_rate: 1.0000e-05
# Epoch 76/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7693 - label_loss: 0.7740 - loss: 1.2282 - sentiment_accuracy: 0.6636 - sentiment_loss: 0.4543 - val_label_accuracy: 0.7771 - val_label_loss: 0.8161 - val_loss: 1.2826 - val_sentiment_accuracy: 0.6517 - val_sentiment_loss: 0.4678 - learning_rate: 1.0000e-05
# Epoch 77/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7725 - label_loss: 0.7675 - loss: 1.2217 - sentiment_accuracy: 0.6585 - sentiment_loss: 0.4542 - val_label_accuracy: 0.7822 - val_label_loss: 0.8169 - val_loss: 1.2837 - val_sentiment_accuracy: 0.6517 - val_sentiment_loss: 0.4682 - learning_rate: 1.0000e-05
# Epoch 78/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7764 - label_loss: 0.7874 - loss: 1.2483 - sentiment_accuracy: 0.6571 - sentiment_loss: 0.4608 - val_label_accuracy: 0.7780 - val_label_loss: 0.8156 - val_loss: 1.2817 - val_sentiment_accuracy: 0.6525 - val_sentiment_loss: 0.4675 - learning_rate: 1.0000e-05
# Epoch 79/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7704 - label_loss: 0.7824 - loss: 1.2402 - sentiment_accuracy: 0.6528 - sentiment_loss: 0.4579 - val_label_accuracy: 0.7822 - val_label_loss: 0.8160 - val_loss: 1.2825 - val_sentiment_accuracy: 0.6517 - val_sentiment_loss: 0.4678 - learning_rate: 1.0000e-05
# Epoch 80/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7661 - label_loss: 0.7786 - loss: 1.2539 - sentiment_accuracy: 0.6553 - sentiment_loss: 0.4753 - val_label_accuracy: 0.7780 - val_label_loss: 0.8153 - val_loss: 1.2806 - val_sentiment_accuracy: 0.6525 - val_sentiment_loss: 0.4666 - learning_rate: 1.0000e-05
# Epoch 81/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7764 - label_loss: 0.7879 - loss: 1.2454 - sentiment_accuracy: 0.6622 - sentiment_loss: 0.4575 - val_label_accuracy: 0.7822 - val_label_loss: 0.8155 - val_loss: 1.2818 - val_sentiment_accuracy: 0.6517 - val_sentiment_loss: 0.4677 - learning_rate: 1.0000e-05
# Epoch 82/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7718 - label_loss: 0.7784 - loss: 1.2345 - sentiment_accuracy: 0.6590 - sentiment_loss: 0.4561 - val_label_accuracy: 0.7771 - val_label_loss: 0.8150 - val_loss: 1.2817 - val_sentiment_accuracy: 0.6534 - val_sentiment_loss: 0.4681 - learning_rate: 1.0000e-05
# Epoch 83/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7743 - label_loss: 0.7695 - loss: 1.2332 - sentiment_accuracy: 0.6553 - sentiment_loss: 0.4636 - val_label_accuracy: 0.7805 - val_label_loss: 0.8146 - val_loss: 1.2820 - val_sentiment_accuracy: 0.6508 - val_sentiment_loss: 0.4688 - learning_rate: 1.0000e-05
# Epoch 84/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7816 - label_loss: 0.7642 - loss: 1.2104 - sentiment_accuracy: 0.6656 - sentiment_loss: 0.4463 - val_label_accuracy: 0.7780 - val_label_loss: 0.8142 - val_loss: 1.2801 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4672 - learning_rate: 1.0000e-05
# Epoch 85/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7723 - label_loss: 0.7825 - loss: 1.2343 - sentiment_accuracy: 0.6512 - sentiment_loss: 0.4518 - val_label_accuracy: 0.7771 - val_label_loss: 0.8162 - val_loss: 1.2825 - val_sentiment_accuracy: 0.6500 - val_sentiment_loss: 0.4676 - learning_rate: 1.0000e-05
# Epoch 86/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7665 - label_loss: 0.7546 - loss: 1.2180 - sentiment_accuracy: 0.6736 - sentiment_loss: 0.4634 - val_label_accuracy: 0.7729 - val_label_loss: 0.8144 - val_loss: 1.2801 - val_sentiment_accuracy: 0.6525 - val_sentiment_loss: 0.4670 - learning_rate: 1.0000e-05
# Epoch 87/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7794 - label_loss: 0.7629 - loss: 1.1999 - sentiment_accuracy: 0.6688 - sentiment_loss: 0.4369 - val_label_accuracy: 0.7831 - val_label_loss: 0.8143 - val_loss: 1.2790 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4660 - learning_rate: 1.0000e-05
# Epoch 88/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7779 - label_loss: 0.7489 - loss: 1.2051 - sentiment_accuracy: 0.6680 - sentiment_loss: 0.4562 - val_label_accuracy: 0.7805 - val_label_loss: 0.8146 - val_loss: 1.2782 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4650 - learning_rate: 1.0000e-05
# Epoch 89/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7694 - label_loss: 0.7801 - loss: 1.2314 - sentiment_accuracy: 0.6588 - sentiment_loss: 0.4514 - val_label_accuracy: 0.7847 - val_label_loss: 0.8155 - val_loss: 1.2794 - val_sentiment_accuracy: 0.6517 - val_sentiment_loss: 0.4653 - learning_rate: 1.0000e-05
# Epoch 90/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7751 - label_loss: 0.7769 - loss: 1.2246 - sentiment_accuracy: 0.6552 - sentiment_loss: 0.4477 - val_label_accuracy: 0.7831 - val_label_loss: 0.8144 - val_loss: 1.2773 - val_sentiment_accuracy: 0.6508 - val_sentiment_loss: 0.4643 - learning_rate: 1.0000e-05
# Epoch 91/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7848 - label_loss: 0.7514 - loss: 1.1873 - sentiment_accuracy: 0.6652 - sentiment_loss: 0.4360 - val_label_accuracy: 0.7814 - val_label_loss: 0.8126 - val_loss: 1.2753 - val_sentiment_accuracy: 0.6441 - val_sentiment_loss: 0.4641 - learning_rate: 1.0000e-05
# Epoch 92/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7684 - label_loss: 0.7866 - loss: 1.2527 - sentiment_accuracy: 0.6501 - sentiment_loss: 0.4660 - val_label_accuracy: 0.7831 - val_label_loss: 0.8129 - val_loss: 1.2776 - val_sentiment_accuracy: 0.6508 - val_sentiment_loss: 0.4661 - learning_rate: 1.0000e-05
# Epoch 93/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7708 - label_loss: 0.7645 - loss: 1.2164 - sentiment_accuracy: 0.6642 - sentiment_loss: 0.4519 - val_label_accuracy: 0.7822 - val_label_loss: 0.8119 - val_loss: 1.2744 - val_sentiment_accuracy: 0.6508 - val_sentiment_loss: 0.4638 - learning_rate: 1.0000e-05
# Epoch 94/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7715 - label_loss: 0.7644 - loss: 1.2202 - sentiment_accuracy: 0.6575 - sentiment_loss: 0.4558 - val_label_accuracy: 0.7831 - val_label_loss: 0.8133 - val_loss: 1.2754 - val_sentiment_accuracy: 0.6517 - val_sentiment_loss: 0.4635 - learning_rate: 1.0000e-05
# Epoch 95/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7785 - label_loss: 0.7654 - loss: 1.2077 - sentiment_accuracy: 0.6652 - sentiment_loss: 0.4423 - val_label_accuracy: 0.7814 - val_label_loss: 0.8118 - val_loss: 1.2732 - val_sentiment_accuracy: 0.6517 - val_sentiment_loss: 0.4628 - learning_rate: 1.0000e-05
# Epoch 96/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7733 - label_loss: 0.7676 - loss: 1.2138 - sentiment_accuracy: 0.6571 - sentiment_loss: 0.4462 - val_label_accuracy: 0.7822 - val_label_loss: 0.8115 - val_loss: 1.2734 - val_sentiment_accuracy: 0.6525 - val_sentiment_loss: 0.4633 - learning_rate: 1.0000e-05
# Epoch 97/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7643 - label_loss: 0.7550 - loss: 1.2022 - sentiment_accuracy: 0.6603 - sentiment_loss: 0.4473 - val_label_accuracy: 0.7814 - val_label_loss: 0.8112 - val_loss: 1.2728 - val_sentiment_accuracy: 0.6534 - val_sentiment_loss: 0.4629 - learning_rate: 1.0000e-05
# Epoch 98/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7691 - label_loss: 0.7693 - loss: 1.2333 - sentiment_accuracy: 0.6525 - sentiment_loss: 0.4641 - val_label_accuracy: 0.7839 - val_label_loss: 0.8131 - val_loss: 1.2749 - val_sentiment_accuracy: 0.6534 - val_sentiment_loss: 0.4632 - learning_rate: 1.0000e-05
# Epoch 99/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7752 - label_loss: 0.7571 - loss: 1.1958 - sentiment_accuracy: 0.6598 - sentiment_loss: 0.4387 - val_label_accuracy: 0.7822 - val_label_loss: 0.8120 - val_loss: 1.2735 - val_sentiment_accuracy: 0.6500 - val_sentiment_loss: 0.4628 - learning_rate: 1.0000e-05
# Epoch 100/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7698 - label_loss: 0.7454 - loss: 1.1959 - sentiment_accuracy: 0.6660 - sentiment_loss: 0.4505 - val_label_accuracy: 0.7797 - val_label_loss: 0.8111 - val_loss: 1.2748 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4650 - learning_rate: 1.0000e-05
# Epoch 101/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7792 - label_loss: 0.7480 - loss: 1.1784 - sentiment_accuracy: 0.6716 - sentiment_loss: 0.4304 - val_label_accuracy: 0.7805 - val_label_loss: 0.8110 - val_loss: 1.2723 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4626 - learning_rate: 1.0000e-05
# Epoch 102/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7661 - label_loss: 0.7719 - loss: 1.2243 - sentiment_accuracy: 0.6467 - sentiment_loss: 0.4524 - val_label_accuracy: 0.7822 - val_label_loss: 0.8104 - val_loss: 1.2721 - val_sentiment_accuracy: 0.6525 - val_sentiment_loss: 0.4631 - learning_rate: 1.0000e-05
# Epoch 103/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - label_accuracy: 0.7796 - label_loss: 0.7309 - loss: 1.1649 - sentiment_accuracy: 0.6792 - sentiment_loss: 0.4339 - val_label_accuracy: 0.7805 - val_label_loss: 0.8101 - val_loss: 1.2693 - val_sentiment_accuracy: 0.6466 - val_sentiment_loss: 0.4606 - learning_rate: 1.0000e-05
# Epoch 104/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - label_accuracy: 0.7750 - label_loss: 0.7548 - loss: 1.1915 - sentiment_accuracy: 0.6682 - sentiment_loss: 0.4367 - val_label_accuracy: 0.7822 - val_label_loss: 0.8102 - val_loss: 1.2697 - val_sentiment_accuracy: 0.6525 - val_sentiment_loss: 0.4609 - learning_rate: 1.0000e-05
# Epoch 105/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - label_accuracy: 0.7806 - label_loss: 0.7461 - loss: 1.1854 - sentiment_accuracy: 0.6693 - sentiment_loss: 0.4393 - val_label_accuracy: 0.7805 - val_label_loss: 0.8100 - val_loss: 1.2694 - val_sentiment_accuracy: 0.6517 - val_sentiment_loss: 0.4607 - learning_rate: 1.0000e-05
# Epoch 106/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7622 - label_loss: 0.7551 - loss: 1.2123 - sentiment_accuracy: 0.6519 - sentiment_loss: 0.4573 - val_label_accuracy: 0.7831 - val_label_loss: 0.8121 - val_loss: 1.2730 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4624 - learning_rate: 1.0000e-05
# Epoch 107/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7727 - label_loss: 0.7640 - loss: 1.2081 - sentiment_accuracy: 0.6527 - sentiment_loss: 0.4441 - val_label_accuracy: 0.7788 - val_label_loss: 0.8088 - val_loss: 1.2692 - val_sentiment_accuracy: 0.6525 - val_sentiment_loss: 0.4617 - learning_rate: 1.0000e-05
# Epoch 108/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7757 - label_loss: 0.7670 - loss: 1.1929 - sentiment_accuracy: 0.6545 - sentiment_loss: 0.4259 - val_label_accuracy: 0.7839 - val_label_loss: 0.8092 - val_loss: 1.2680 - val_sentiment_accuracy: 0.6500 - val_sentiment_loss: 0.4602 - learning_rate: 1.0000e-05
# Epoch 109/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7791 - label_loss: 0.7440 - loss: 1.1856 - sentiment_accuracy: 0.6663 - sentiment_loss: 0.4416 - val_label_accuracy: 0.7831 - val_label_loss: 0.8101 - val_loss: 1.2682 - val_sentiment_accuracy: 0.6508 - val_sentiment_loss: 0.4595 - learning_rate: 1.0000e-05
# Epoch 110/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7765 - label_loss: 0.7503 - loss: 1.1883 - sentiment_accuracy: 0.6673 - sentiment_loss: 0.4379 - val_label_accuracy: 0.7805 - val_label_loss: 0.8094 - val_loss: 1.2687 - val_sentiment_accuracy: 0.6517 - val_sentiment_loss: 0.4606 - learning_rate: 1.0000e-05
# Epoch 111/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7726 - label_loss: 0.7703 - loss: 1.2217 - sentiment_accuracy: 0.6521 - sentiment_loss: 0.4514 - val_label_accuracy: 0.7805 - val_label_loss: 0.8098 - val_loss: 1.2689 - val_sentiment_accuracy: 0.6525 - val_sentiment_loss: 0.4604 - learning_rate: 1.0000e-05
# Epoch 112/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7774 - label_loss: 0.7554 - loss: 1.1965 - sentiment_accuracy: 0.6617 - sentiment_loss: 0.4410 - val_label_accuracy: 0.7831 - val_label_loss: 0.8101 - val_loss: 1.2685 - val_sentiment_accuracy: 0.6508 - val_sentiment_loss: 0.4597 - learning_rate: 1.0000e-05
# Epoch 113/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7838 - label_loss: 0.7614 - loss: 1.1828 - sentiment_accuracy: 0.6540 - sentiment_loss: 0.4214 - val_label_accuracy: 0.7831 - val_label_loss: 0.8089 - val_loss: 1.2683 - val_sentiment_accuracy: 0.6500 - val_sentiment_loss: 0.4607 - learning_rate: 1.0000e-05
# Epoch 114/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7766 - label_loss: 0.7410 - loss: 1.1824 - sentiment_accuracy: 0.6605 - sentiment_loss: 0.4414 - val_label_accuracy: 0.7805 - val_label_loss: 0.8077 - val_loss: 1.2660 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4596 - learning_rate: 2.0000e-06
# Epoch 115/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7767 - label_loss: 0.7547 - loss: 1.1786 - sentiment_accuracy: 0.6536 - sentiment_loss: 0.4239 - val_label_accuracy: 0.7805 - val_label_loss: 0.8077 - val_loss: 1.2655 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4591 - learning_rate: 2.0000e-06
# Epoch 116/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7733 - label_loss: 0.7746 - loss: 1.2065 - sentiment_accuracy: 0.6426 - sentiment_loss: 0.4319 - val_label_accuracy: 0.7805 - val_label_loss: 0.8076 - val_loss: 1.2654 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4591 - learning_rate: 2.0000e-06
# Epoch 117/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7745 - label_loss: 0.7488 - loss: 1.1850 - sentiment_accuracy: 0.6572 - sentiment_loss: 0.4362 - val_label_accuracy: 0.7805 - val_label_loss: 0.8077 - val_loss: 1.2654 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4591 - learning_rate: 2.0000e-06
# Epoch 118/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7792 - label_loss: 0.7538 - loss: 1.1880 - sentiment_accuracy: 0.6641 - sentiment_loss: 0.4342 - val_label_accuracy: 0.7805 - val_label_loss: 0.8076 - val_loss: 1.2653 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4591 - learning_rate: 2.0000e-06
# Epoch 119/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7759 - label_loss: 0.7508 - loss: 1.1861 - sentiment_accuracy: 0.6598 - sentiment_loss: 0.4353 - val_label_accuracy: 0.7797 - val_label_loss: 0.8076 - val_loss: 1.2652 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4590 - learning_rate: 2.0000e-06
# Epoch 120/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7755 - label_loss: 0.7542 - loss: 1.1863 - sentiment_accuracy: 0.6505 - sentiment_loss: 0.4321 - val_label_accuracy: 0.7797 - val_label_loss: 0.8074 - val_loss: 1.2650 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4589 - learning_rate: 2.0000e-06
# Epoch 121/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7728 - label_loss: 0.7578 - loss: 1.1780 - sentiment_accuracy: 0.6530 - sentiment_loss: 0.4202 - val_label_accuracy: 0.7797 - val_label_loss: 0.8074 - val_loss: 1.2650 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4590 - learning_rate: 2.0000e-06
# Epoch 122/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7772 - label_loss: 0.7415 - loss: 1.1856 - sentiment_accuracy: 0.6662 - sentiment_loss: 0.4442 - val_label_accuracy: 0.7814 - val_label_loss: 0.8075 - val_loss: 1.2650 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4588 - learning_rate: 2.0000e-06
# Epoch 123/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7783 - label_loss: 0.7445 - loss: 1.1804 - sentiment_accuracy: 0.6654 - sentiment_loss: 0.4359 - val_label_accuracy: 0.7805 - val_label_loss: 0.8077 - val_loss: 1.2650 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4587 - learning_rate: 2.0000e-06
# Epoch 124/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7843 - label_loss: 0.7462 - loss: 1.1571 - sentiment_accuracy: 0.6622 - sentiment_loss: 0.4109 - val_label_accuracy: 0.7805 - val_label_loss: 0.8078 - val_loss: 1.2652 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 2.0000e-06
# Epoch 125/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7819 - label_loss: 0.7376 - loss: 1.1660 - sentiment_accuracy: 0.6639 - sentiment_loss: 0.4285 - val_label_accuracy: 0.7814 - val_label_loss: 0.8080 - val_loss: 1.2654 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 2.0000e-06
# Epoch 126/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7758 - label_loss: 0.7511 - loss: 1.1843 - sentiment_accuracy: 0.6720 - sentiment_loss: 0.4331 - val_label_accuracy: 0.7805 - val_label_loss: 0.8076 - val_loss: 1.2650 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4588 - learning_rate: 4.0000e-07
# Epoch 127/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7755 - label_loss: 0.7508 - loss: 1.1798 - sentiment_accuracy: 0.6557 - sentiment_loss: 0.4289 - val_label_accuracy: 0.7805 - val_label_loss: 0.8073 - val_loss: 1.2648 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4588 - learning_rate: 4.0000e-07
# Epoch 128/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7775 - label_loss: 0.7570 - loss: 1.1835 - sentiment_accuracy: 0.6537 - sentiment_loss: 0.4265 - val_label_accuracy: 0.7788 - val_label_loss: 0.8072 - val_loss: 1.2647 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 4.0000e-07
# Epoch 129/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7798 - label_loss: 0.7514 - loss: 1.1800 - sentiment_accuracy: 0.6573 - sentiment_loss: 0.4286 - val_label_accuracy: 0.7797 - val_label_loss: 0.8072 - val_loss: 1.2646 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 4.0000e-07
# Epoch 130/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7730 - label_loss: 0.7447 - loss: 1.1786 - sentiment_accuracy: 0.6647 - sentiment_loss: 0.4338 - val_label_accuracy: 0.7797 - val_label_loss: 0.8072 - val_loss: 1.2645 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 4.0000e-07
# Epoch 131/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7733 - label_loss: 0.7500 - loss: 1.1868 - sentiment_accuracy: 0.6582 - sentiment_loss: 0.4368 - val_label_accuracy: 0.7788 - val_label_loss: 0.8072 - val_loss: 1.2646 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 4.0000e-07
# Epoch 132/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7668 - label_loss: 0.7543 - loss: 1.1983 - sentiment_accuracy: 0.6570 - sentiment_loss: 0.4440 - val_label_accuracy: 0.7788 - val_label_loss: 0.8072 - val_loss: 1.2646 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4588 - learning_rate: 4.0000e-07
# Epoch 133/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7735 - label_loss: 0.7521 - loss: 1.1733 - sentiment_accuracy: 0.6591 - sentiment_loss: 0.4213 - val_label_accuracy: 0.7797 - val_label_loss: 0.8071 - val_loss: 1.2645 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4587 - learning_rate: 4.0000e-07
# Epoch 134/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7807 - label_loss: 0.7384 - loss: 1.1737 - sentiment_accuracy: 0.6608 - sentiment_loss: 0.4353 - val_label_accuracy: 0.7797 - val_label_loss: 0.8071 - val_loss: 1.2645 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4587 - learning_rate: 4.0000e-07
# Epoch 135/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7720 - label_loss: 0.7483 - loss: 1.1781 - sentiment_accuracy: 0.6568 - sentiment_loss: 0.4298 - val_label_accuracy: 0.7788 - val_label_loss: 0.8071 - val_loss: 1.2645 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 4.0000e-07
# Epoch 136/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7818 - label_loss: 0.7420 - loss: 1.1753 - sentiment_accuracy: 0.6577 - sentiment_loss: 0.4333 - val_label_accuracy: 0.7797 - val_label_loss: 0.8071 - val_loss: 1.2645 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 1.0000e-07
# Epoch 137/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7860 - label_loss: 0.7399 - loss: 1.1594 - sentiment_accuracy: 0.6692 - sentiment_loss: 0.4195 - val_label_accuracy: 0.7797 - val_label_loss: 0.8071 - val_loss: 1.2645 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 1.0000e-07
# Epoch 138/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7763 - label_loss: 0.7361 - loss: 1.1613 - sentiment_accuracy: 0.6712 - sentiment_loss: 0.4252 - val_label_accuracy: 0.7797 - val_label_loss: 0.8071 - val_loss: 1.2645 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 1.0000e-07
# Epoch 139/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7766 - label_loss: 0.7578 - loss: 1.1997 - sentiment_accuracy: 0.6547 - sentiment_loss: 0.4420 - val_label_accuracy: 0.7797 - val_label_loss: 0.8071 - val_loss: 1.2645 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 1.0000e-07
# Epoch 140/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7785 - label_loss: 0.7527 - loss: 1.1860 - sentiment_accuracy: 0.6535 - sentiment_loss: 0.4332 - val_label_accuracy: 0.7797 - val_label_loss: 0.8071 - val_loss: 1.2645 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 1.0000e-07
# Epoch 141/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7808 - label_loss: 0.7529 - loss: 1.1735 - sentiment_accuracy: 0.6558 - sentiment_loss: 0.4206 - val_label_accuracy: 0.7797 - val_label_loss: 0.8071 - val_loss: 1.2645 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 1.0000e-07
# Epoch 142/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7662 - label_loss: 0.7570 - loss: 1.1920 - sentiment_accuracy: 0.6465 - sentiment_loss: 0.4349 - val_label_accuracy: 0.7797 - val_label_loss: 0.8071 - val_loss: 1.2645 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 1.0000e-07
# Epoch 143/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7805 - label_loss: 0.7479 - loss: 1.1760 - sentiment_accuracy: 0.6643 - sentiment_loss: 0.4281 - val_label_accuracy: 0.7797 - val_label_loss: 0.8071 - val_loss: 1.2645 - val_sentiment_accuracy: 0.6483 - val_sentiment_loss: 0.4587 - learning_rate: 1.0000e-07
# Epoch 144/1000
# ...
# Epoch 674/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7721 - label_loss: 0.7444 - loss: 1.1845 - sentiment_accuracy: 0.6535 - sentiment_loss: 0.4401 - val_label_accuracy: 0.7788 - val_label_loss: 0.8060 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4579 - learning_rate: 1.0000e-07
# Epoch 675/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7847 - label_loss: 0.7428 - loss: 1.1501 - sentiment_accuracy: 0.6619 - sentiment_loss: 0.4072 - val_label_accuracy: 0.7788 - val_label_loss: 0.8060 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4579 - learning_rate: 1.0000e-07
# Epoch 676/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7784 - label_loss: 0.7587 - loss: 1.1856 - sentiment_accuracy: 0.6552 - sentiment_loss: 0.4269 - val_label_accuracy: 0.7788 - val_label_loss: 0.8060 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4579 - learning_rate: 1.0000e-07
# Epoch 677/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7715 - label_loss: 0.7423 - loss: 1.1744 - sentiment_accuracy: 0.6588 - sentiment_loss: 0.4321 - val_label_accuracy: 0.7788 - val_label_loss: 0.8060 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4579 - learning_rate: 1.0000e-07
# Epoch 678/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7671 - label_loss: 0.7431 - loss: 1.1814 - sentiment_accuracy: 0.6645 - sentiment_loss: 0.4383 - val_label_accuracy: 0.7788 - val_label_loss: 0.8060 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4579 - learning_rate: 1.0000e-07
# Epoch 679/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7765 - label_loss: 0.7638 - loss: 1.1809 - sentiment_accuracy: 0.6449 - sentiment_loss: 0.4172 - val_label_accuracy: 0.7788 - val_label_loss: 0.8060 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 680/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7791 - label_loss: 0.7358 - loss: 1.1726 - sentiment_accuracy: 0.6655 - sentiment_loss: 0.4369 - val_label_accuracy: 0.7788 - val_label_loss: 0.8060 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4579 - learning_rate: 1.0000e-07
# Epoch 681/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7621 - label_loss: 0.7601 - loss: 1.2271 - sentiment_accuracy: 0.6561 - sentiment_loss: 0.4669 - val_label_accuracy: 0.7788 - val_label_loss: 0.8060 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4579 - learning_rate: 1.0000e-07
# Epoch 682/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7807 - label_loss: 0.7270 - loss: 1.1488 - sentiment_accuracy: 0.6767 - sentiment_loss: 0.4218 - val_label_accuracy: 0.7788 - val_label_loss: 0.8060 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4579 - learning_rate: 1.0000e-07
# Epoch 683/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7817 - label_loss: 0.7570 - loss: 1.1758 - sentiment_accuracy: 0.6571 - sentiment_loss: 0.4188 - val_label_accuracy: 0.7788 - val_label_loss: 0.8060 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 684/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7784 - label_loss: 0.7433 - loss: 1.1822 - sentiment_accuracy: 0.6654 - sentiment_loss: 0.4389 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 685/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7723 - label_loss: 0.7428 - loss: 1.1709 - sentiment_accuracy: 0.6619 - sentiment_loss: 0.4281 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4579 - learning_rate: 1.0000e-07
# Epoch 686/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7749 - label_loss: 0.7398 - loss: 1.1606 - sentiment_accuracy: 0.6639 - sentiment_loss: 0.4208 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 687/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7824 - label_loss: 0.7421 - loss: 1.1463 - sentiment_accuracy: 0.6698 - sentiment_loss: 0.4043 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 688/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7874 - label_loss: 0.7371 - loss: 1.1588 - sentiment_accuracy: 0.6619 - sentiment_loss: 0.4217 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 689/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7749 - label_loss: 0.7386 - loss: 1.1654 - sentiment_accuracy: 0.6624 - sentiment_loss: 0.4268 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2625 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 690/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7744 - label_loss: 0.7339 - loss: 1.1598 - sentiment_accuracy: 0.6668 - sentiment_loss: 0.4259 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 691/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7752 - label_loss: 0.7433 - loss: 1.1745 - sentiment_accuracy: 0.6571 - sentiment_loss: 0.4312 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 692/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - label_accuracy: 0.7734 - label_loss: 0.7399 - loss: 1.1742 - sentiment_accuracy: 0.6545 - sentiment_loss: 0.4342 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 693/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7826 - label_loss: 0.7323 - loss: 1.1556 - sentiment_accuracy: 0.6665 - sentiment_loss: 0.4232 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 694/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7729 - label_loss: 0.7602 - loss: 1.1854 - sentiment_accuracy: 0.6492 - sentiment_loss: 0.4251 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 695/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7765 - label_loss: 0.7488 - loss: 1.1763 - sentiment_accuracy: 0.6572 - sentiment_loss: 0.4275 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 696/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7619 - label_loss: 0.7563 - loss: 1.2101 - sentiment_accuracy: 0.6526 - sentiment_loss: 0.4537 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 697/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7790 - label_loss: 0.7335 - loss: 1.1617 - sentiment_accuracy: 0.6702 - sentiment_loss: 0.4282 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 698/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7677 - label_loss: 0.7435 - loss: 1.1747 - sentiment_accuracy: 0.6611 - sentiment_loss: 0.4312 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 699/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7725 - label_loss: 0.7388 - loss: 1.1750 - sentiment_accuracy: 0.6684 - sentiment_loss: 0.4362 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 700/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7791 - label_loss: 0.7420 - loss: 1.1733 - sentiment_accuracy: 0.6693 - sentiment_loss: 0.4313 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 701/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7794 - label_loss: 0.7429 - loss: 1.1759 - sentiment_accuracy: 0.6674 - sentiment_loss: 0.4330 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 702/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7767 - label_loss: 0.7531 - loss: 1.1828 - sentiment_accuracy: 0.6577 - sentiment_loss: 0.4297 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 703/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7886 - label_loss: 0.7465 - loss: 1.1575 - sentiment_accuracy: 0.6583 - sentiment_loss: 0.4110 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 704/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7769 - label_loss: 0.7500 - loss: 1.1878 - sentiment_accuracy: 0.6614 - sentiment_loss: 0.4379 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 705/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7724 - label_loss: 0.7474 - loss: 1.1777 - sentiment_accuracy: 0.6558 - sentiment_loss: 0.4302 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 706/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7747 - label_loss: 0.7446 - loss: 1.1651 - sentiment_accuracy: 0.6611 - sentiment_loss: 0.4205 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 707/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7624 - label_loss: 0.7621 - loss: 1.2087 - sentiment_accuracy: 0.6482 - sentiment_loss: 0.4466 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 708/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7787 - label_loss: 0.7264 - loss: 1.1459 - sentiment_accuracy: 0.6764 - sentiment_loss: 0.4195 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 709/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7757 - label_loss: 0.7438 - loss: 1.1843 - sentiment_accuracy: 0.6536 - sentiment_loss: 0.4405 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 710/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7696 - label_loss: 0.7404 - loss: 1.1772 - sentiment_accuracy: 0.6562 - sentiment_loss: 0.4368 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 711/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7753 - label_loss: 0.7357 - loss: 1.1666 - sentiment_accuracy: 0.6651 - sentiment_loss: 0.4310 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 712/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7698 - label_loss: 0.7575 - loss: 1.2058 - sentiment_accuracy: 0.6448 - sentiment_loss: 0.4483 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 713/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7784 - label_loss: 0.7417 - loss: 1.1809 - sentiment_accuracy: 0.6606 - sentiment_loss: 0.4392 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 714/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7707 - label_loss: 0.7553 - loss: 1.1871 - sentiment_accuracy: 0.6439 - sentiment_loss: 0.4319 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2623 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 715/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7689 - label_loss: 0.7505 - loss: 1.1931 - sentiment_accuracy: 0.6609 - sentiment_loss: 0.4425 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2624 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 716/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7742 - label_loss: 0.7461 - loss: 1.1864 - sentiment_accuracy: 0.6576 - sentiment_loss: 0.4403 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2623 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 717/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7825 - label_loss: 0.7377 - loss: 1.1714 - sentiment_accuracy: 0.6731 - sentiment_loss: 0.4337 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2623 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 718/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7727 - label_loss: 0.7438 - loss: 1.1745 - sentiment_accuracy: 0.6591 - sentiment_loss: 0.4307 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2623 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 719/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7738 - label_loss: 0.7424 - loss: 1.1948 - sentiment_accuracy: 0.6622 - sentiment_loss: 0.4524 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2623 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 720/1000
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - label_accuracy: 0.7658 - label_loss: 0.7387 - loss: 1.1928 - sentiment_accuracy: 0.6614 - sentiment_loss: 0.4542 - val_label_accuracy: 0.7788 - val_label_loss: 0.8059 - val_loss: 1.2623 - val_sentiment_accuracy: 0.6492 - val_sentiment_loss: 0.4578 - learning_rate: 1.0000e-07
# Epoch 721/1000
# 124/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - label_accuracy: 0.7777 - label_loss: 0.7457 - loss: 1.1772 - sentiment_accuracy: 0.6586 - sentiment_loss: 0.4315

# %%
df_reviews

# %% [markdown]
# ## Training History

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['sentiment_accuracy'], label='sentiment_accuracy')
plt.plot(history.history['val_sentiment_accuracy'], label='val_sentiment_accuracy')
plt.title('Sentiment Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['label_accuracy'], label='label_accuracy')
plt.plot(history.history['val_label_accuracy'], label='val_label_accuracy')
plt.title('Label Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Evaluate Model Performance

# %%
evaluation_metrics = evaluate_model(model, X_test, y_sentiment_test, y_label_test, 
                                  sentiment_encoder, label_encoder)

# %% [markdown]
# ## Try Predictions

# %%
text = "Sayangnya pengiriman lebih lambat dari jadwal. Produk tetap sampai dengan baik, tetapi semoga pengiriman bisa lebih cepat di masa depan."
sentiment, label = predict_text(
    text,
    model,
    tokenizer,
    sentiment_encoder,
    label_encoder,
    max_len
)
print(f"Sentiment: {sentiment}")
print(f"Label: {label}")

# %% [markdown]
# # WordCloud

# %% [markdown]
# ## Positive

# %%
df_reviews.head(1)

# %%
word_list = []
for text in df_reviews[df_reviews['sentimen']=='positive']['stemmed_reviews']:
  for word in text:
    if word.isnumeric() == False:
      word_list.append(word)
x = Counter(word_list)
print(len(x))
d = {k: v for k, v in sorted(x.items(), key=lambda item: item[0], reverse=False)}
wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(d)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.title('\nPOSITIVE\n')

# %% [markdown]
# ## Neutral

# %%
word_list = []
for text in df_reviews[df_reviews['sentimen']=='neutral']['stemmed_reviews']:
  for word in text:
    if word.isnumeric() == False:
      word_list.append(word)
x = Counter(word_list)
print(len(x))
d = {k: v for k, v in sorted(x.items(), key=lambda item: item[0], reverse=False)}
wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(d)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.title('\nNEUTRAL\n')

# %% [markdown]
# ## Negative

# %%
word_list = []
for text in df_reviews[df_reviews['sentimen']=='negative']['stemmed_reviews']:
  for word in text:
    if word.isnumeric() == False:
      word_list.append(word)
x = Counter(word_list)
print(len(x))
d = {k: v for k, v in sorted(x.items(), key=lambda item: item[0], reverse=False)}
wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(d)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.title('\nNEGATIVE\n')

# %%
df_reviews.label.unique()

# %% [markdown]
# ## Trusted

# %%
word_list = []
for text in df_reviews[df_reviews['label']=='trusted']['stemmed_reviews']:
  for word in text:
    if word.isnumeric() == False:
      word_list.append(word)
x = Counter(word_list)
print(len(x))
d = {k: v for k, v in sorted(x.items(), key=lambda item: item[0], reverse=False)}
wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(d)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.title('\nTRUSTED\n')

# %% [markdown]
# ## Non

# %%
word_list = []
for text in df_reviews[df_reviews['label']=='non']['stemmed_reviews']:
  for word in text:
    if word.isnumeric() == False:
      word_list.append(word)
x = Counter(word_list)
print(len(x))
d = {k: v for k, v in sorted(x.items(), key=lambda item: item[0], reverse=False)}
wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(d)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.title('\nNON\n')

# %% [markdown]
# ## Fake

# %%
word_list = []
for text in df_reviews[df_reviews['label']=='fake']['stemmed_reviews']:
  for word in text:
    if word.isnumeric() == False:
      word_list.append(word)
x = Counter(word_list)
print(len(x))
d = {k: v for k, v in sorted(x.items(), key=lambda item: item[0], reverse=False)}
wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(d)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.title('\nNON\n')
